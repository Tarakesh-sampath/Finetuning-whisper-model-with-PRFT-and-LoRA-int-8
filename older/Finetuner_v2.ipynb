# %%
# !pip3 install transformers datasets accelerate librosa
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124   
# !pip install "tensorboard==1.14.0"
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (4.46.3)
# Requirement already satisfied: datasets in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (3.1.0)
# Requirement already satisfied: torchaudio in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (2.5.1+cu124)
# Requirement already satisfied: accelerate in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (1.1.1)
# Requirement already satisfied: librosa in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (0.10.2.post1)
# Requirement already satisfied: filelock in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from datasets) (3.11.8)
# Requirement already satisfied: torch==2.5.1+cu124 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torchaudio) (2.5.1+cu124)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torch==2.5.1+cu124->torchaudio) (4.12.2)
# Requirement already satisfied: networkx in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torch==2.5.1+cu124->torchaudio) (3.2.1)
# Requirement already satisfied: jinja2 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torch==2.5.1+cu124->torchaudio) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torch==2.5.1+cu124->torchaudio) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from sympy==1.13.1->torch==2.5.1+cu124->torchaudio) (1.3.0)
# Requirement already satisfied: psutil in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from accelerate) (6.1.0)
# Requirement already satisfied: audioread>=2.1.9 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from aiohttp->datasets) (1.18.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: colorama in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: pycparser in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: six>=1.5 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from jinja2->torch==2.5.1+cu124->torchaudio) (3.0.2)
# Looking in indexes: https://download.pytorch.org/whl/cu124, https://pypi.ngc.nvidia.com
# Requirement already satisfied: torch in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (0.20.1+cu124)
# Requirement already satisfied: torchaudio in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (2.5.1+cu124)
# Requirement already satisfied: filelock in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\work\vs_code_doc\repo\finetuning-whisper-model-with-prft-and-lora-int-8\env\lib\site-packages (from jinja2->torch) (3.0.2)

# %%
import torch
from datasets import load_dataset
from transformers import (
    WhisperFeatureExtractor, 
    WhisperTokenizer, 
    WhisperProcessor,
    WhisperForConditionalGeneration,
    Seq2SeqTrainingArguments, 
    Seq2SeqTrainer
)
from dataclasses import dataclass
from typing import Any, Dict, List, Union

# 1. Load your dataset from Hugging Face
# Replace 'your-username/your-dataset' with your actual dataset
dataset = load_dataset("Tarakeshwaran/Whisper-train-data")

# 2. Load pre-trained Whisper model and processors
model_name = "openai/whisper-small"  # You can choose different sizes
feature_extractor = WhisperFeatureExtractor.from_pretrained(model_name)
tokenizer = WhisperTokenizer.from_pretrained(model_name)
processor = WhisperProcessor.from_pretrained(model_name)
model = WhisperForConditionalGeneration.from_pretrained(model_name)

# 3. Prepare the dataset
def prepare_dataset(batch):
    # Assuming your dataset has 'audio' and 'text' columns
    # Adjust based on your actual dataset structure
    audio = batch['audio']
    text = batch['text']
    
    # Process audio
    input_features = feature_extractor(
        audio['array'], 
        sampling_rate=audio['sampling_rate'], 
        return_tensors="pt"
    ).input_features
    
    # Encode text
    labels = tokenizer(text).input_ids
    
    return {
        "input_features": input_features.squeeze(),
        "labels": labels
    }

# Prepare train and eval datasets
prepared_dataset = dataset.map(prepare_dataset, remove_columns=dataset['train'].column_names)

# 4. Data Collator
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any
    padding: bool = True
    max_length: int = None
    pad_to_multiple_of: int = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # Prepare input features
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(
            input_features, 
            return_tensors="pt",
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of
        )

        # Prepare labels
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        labels_batch = self.processor.tokenizer.pad(
            label_features, 
            return_tensors="pt",
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of
        )

        # Replace padding with -100 to ignore loss on padding tokens
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        return {
            "input_features": batch["input_features"],
            "labels": labels,
            # Only add attention_mask if it exists
            **({"attention_mask": batch.get("attention_mask")} if "attention_mask" in batch else {})
        }

data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# 5. Training Arguments
training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-fine-tuned",
    per_device_train_batch_size=16,
    gradient_accumulation_steps=1,
    learning_rate=1e-5,
    warmup_steps=500,
    max_steps=4000,
    gradient_checkpointing=True,
    fp16=True,
    evaluation_strategy="steps",
    save_strategy="steps",
    save_steps=1000,
    eval_steps=1000,
    logging_steps=200,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False
)

# 6. Trainer
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=prepared_dataset["train"],
    eval_dataset=prepared_dataset["test"],
    data_collator=data_collator,
    # Optional: Add compute_metrics if you want to track WER
    # compute_metrics=compute_metrics  # You'd need to define this function
)

# 7. Train the model
trainer.train()

# 8. Save the fine-tuned model
trainer.save_model("./whisper-fine-tuned")
# Out:
# max_steps is given, it will override any value given in num_train_epochs
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 124
#     113 trainer = Seq2SeqTrainer(
#     114     args=training_args,
#     115     model=model,
#    (...)
#     120     # compute_metrics=compute_metrics  # You'd need to define this function
#     121 )
#     123 # 7. Train the model
# --> 124 trainer.train()
#     126 # 8. Save the fine-tuned model
#     127 trainer.save_model("./whisper-fine-tuned")
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\transformers\trainer.py:2123, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2121         hf_hub_utils.enable_progress_bars()
#    2122 else:
# -> 2123     return inner_training_loop(
#    2124         args=args,
#    2125         resume_from_checkpoint=resume_from_checkpoint,
#    2126         trial=trial,
#    2127         ignore_keys_for_eval=ignore_keys_for_eval,
#    2128     )
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\transformers\trainer.py:2481, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2475 context = (
#    2476     functools.partial(self.accelerator.no_sync, model=model)
#    2477     if i != len(batch_samples) - 1
#    2478     else contextlib.nullcontext
#    2479 )
#    2480 with context():
# -> 2481     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2483 if (
#    2484     args.logging_nan_inf_filter
#    2485     and not is_torch_xla_available()
#    2486     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2487 ):
#    2488     # if loss is nan or inf simply add the average of previous logged losses
#    2489     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\transformers\trainer.py:3612, in Trainer.training_step(***failed resolving arguments***)
#    3610         scaled_loss.backward()
#    3611 else:
# -> 3612     self.accelerator.backward(loss, **kwargs)
#    3613     # Finally we need to normalize the loss for reporting
#    3614     if num_items_in_batch is None:
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\accelerate\accelerator.py:2241, in Accelerator.backward(self, loss, **kwargs)
#    2239     self.lomo_backward(loss, learning_rate)
#    2240 else:
# -> 2241     loss.backward(**kwargs)
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\torch\autograd\function.py:307, in BackwardCFunction.apply(self, *args)
#     301     raise RuntimeError(
#     302         "Implementing both 'backward' and 'vjp' for a custom "
#     303         "Function is not allowed. You should only implement one "
#     304         "of them."
#     305     )
#     306 user_fn = vjp_fn if vjp_fn is not Function.vjp else backward_fn
# --> 307 return user_fn(self, *args)
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\torch\utils\checkpoint.py:321, in CheckpointFunction.backward(ctx, *args)
#     316 if len(outputs_with_grad) == 0:
#     317     raise RuntimeError(
#     318         "none of output has requires_grad=True,"
#     319         " this checkpoint() is not necessary"
#     320     )
# --> 321 torch.autograd.backward(outputs_with_grad, args_with_grad)
#     322 grads = tuple(
#     323     inp.grad if isinstance(inp, torch.Tensor) else None
#     324     for inp in detached_inputs
#     325 )
#     327 return (None, None) + grads
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File d:\Work\vs_code_doc\repo\Finetuning-whisper-model-with-PRFT-and-LoRA-int-8\env\lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:
